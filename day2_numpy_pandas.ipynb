# %%
import numpy as np

# %%
marks=np.array([49,48,33,44,46,45])

# %%
marks
# Out:
# array([49, 48, 33, 44, 46, 45])

# %%
marks.max()
# Out:
# np.int64(49)

# %%
marks.mean()
# Out:
# np.float64(44.166666666666664)

# %%
marks.min()
# Out:
# np.int64(33)

# %%
marks*2
# Out:
# array([98, 96, 66, 88, 92, 90])

# %%
marks
# Out:
# array([49, 48, 33, 44, 46, 45])

# %%
marks>40
# Out:
# array([ True,  True, False,  True,  True,  True])

# %%
marks[marks>40]
# Out:
# array([49, 48, 44, 46, 45])

# %%
import pandas as pd

# %%
import pandas as pd

data = {
    "name": ["A", "B", "C", "D", "E"],
    "marks": [65, 78, 90, 82, 74]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   name  marks
# 0    A     65
# 1    B     78
# 2    C     90
# 3    D     82
# 4    E     74

# %%
df.head()
# Out:
#   name  marks
# 0    A     65
# 1    B     78
# 2    C     90
# 3    D     82
# 4    E     74

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    5 non-null      object
#  1   marks   5 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 212.0+ bytes

# %%
df.describe
# Out:
# <bound method NDFrame.describe of   name  marks
# 0    A     65
# 1    B     78
# 2    C     90
# 3    D     82
# 4    E     74>

# %%
df["marks"].mean()
# Out:
# np.float64(77.8)

# %%
df["marks"].max()
# Out:
# 90

# %%
df[df["marks"]>75]
# Out:
#   name  marks
# 1    B     78
# 2    C     90
# 3    D     82

# %% [markdown]
# PANDAS MINI INSIGHT
# Avg Marks
# Number of students above 80
# One Decision Sentence

# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\harss\\45DAY ROADMAP'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'BASICSDAY_1.ipynb',
#  'day2_numpy_pandas.ipynb',
#  'Maths.csv',
#  'Portuguese.csv',
#  'student_scores.csv.txt']

# %%
import pandas as pd

# %%
df = pd.read_csv("student_scores.csv")

# %%
df.head()
# Out:
#    student_id     name  maths  science  english
# 0           1    Alice     78       85       74
# 1           2      Bob     65       70       68
# 2           3  Charlie     90       92       88
# 3           4    David     55       60       58
# 4           5      Eva     82       88       80

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['student_id', 'name', 'maths', 'science', 'english'], dtype='object')
