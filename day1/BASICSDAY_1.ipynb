# %%
import sys
print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]

# %%
print("This is my Day1 and i started my career step by step")
# Out:
# This is my Day1 and i started my career step by step

# %%
name="HarshithKumar"
age=21
cgpa=7.2

# %%
type(name)
type(age)
type(cgpa)
# Out:
# float

# %%
type(age)
# Out:
# int

# %%
type(cgpa)
# Out:
# float

# %%
name = input("Enter your name : ")
# Out:
# Enter your name :  HarshtihKumar

# %%
age= int(input("Enter your age: "))
# Out:
# Enter your age:  21

# %%
if age>18:
    print("Elgible to cast vote")
else:
    print("Not eligible")
# Out:
# Elgible to cast vote

# %%
if age>18:
    print(f"{name} is elgible for interships")
else:
    print(f"{name} is learning and growing")
# Out:
# HarshtihKumar is elgible for interships

# %%
marks =[75,55,94,66,88,74,98]

# %%
avg = sum(marks) / len(marks)

# %%
avg
# Out:
# 78.57142857142857

# %%
scores=[75,78,88,93,117]

# %%
scores
# Out:
# [75, 78, 88, 93, 117]

# %%
len(scores)
# Out:
# 5

# %%
min(scores)
# Out:
# 75

# %%
max(scores)
# Out:
# 117

# %%
sum(scores)
# Out:
# 451

# %%
for score in scores:
    print(score)
# Out:
# 75
# 78
# 88
# 93
# 117

# %%
for score in scores:
    if score>=80:
        print(score, "is good")
# Out:
# 88 is good
# 93 is good
# 117 is good

# %%
student = {
    "name": "Harshith",
     "age": 21,
     "cgpa" : 7.2
}

# %%
student["age"]
# Out:
# 21

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'cgpa'])

# %%
student.values()
# Out:
# dict_values(['Harshith', 21, 7.2])

# %%
students = [
    {"name": "A", "marks": 70},
    {"name": "B", "marks": 85},
    {"name": "C", "marks": 90}
]

students
# Out:
# [{'name': 'A', 'marks': 70},
#  {'name': 'B', 'marks': 85},
#  {'name': 'C', 'marks': 90}]

# %%
high_scorers = []

for s in students:
    if s["marks"] >= 80:
        high_scorers.append(s)

high_scorers
# Out:
# [{'name': 'B', 'marks': 85}, {'name': 'C', 'marks': 90}]

# %%
high_scorers=[]

for s in students:
    if s["marks"]>=80:
        high_scorers.append(s)

high_scorers
# Out:
# [{'name': 'B', 'marks': 85}, {'name': 'C', 'marks': 90}]

# %%
total =0 

for s in students:
    total +=s["marks"]
average = total/ len(students)

# %%
average
# Out:
# 81.66666666666667
